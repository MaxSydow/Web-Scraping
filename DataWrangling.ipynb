# %% [markdown]
# # Data Wrangling Using OpenStreetMap
# Max Sydow, WGU BS Data Management and Data Analytics, Udacity Data Wrangling course
#
#
# # Introduction
#
#      The central portion of the city of Minneapolis, Mn was extracted from the OpenStreetMap Overpass API as an XML file.  I chose this city, because I grew up there and am currently missing it's mild summers.  Data such as street names, and zip codes can be extracted from tags in the XML file using Python's iterparse() method.  The data as elements inside the tags were then used to populate csv's.  These csv's were then used to populate tables in a SQL data base using Python's sqlite3 package.  From here the data can be explored using queries, and further cleaned with Python.
#
# # Preparing the Data
#
#     The size of the Minneapolis.osm file is 66.9 MB.  The following code loads the file, iterativly parses it, then writes to csv's.   Their sizes are as follows:
#     nodes.csv             23.7  MB
#     nodes_tags.csv        2.98 MB
#     ways.csv              2.94  MB
#     ways_nodes.csv        9.95 MB
#     ways_tags.csv         4.85 MB

# %%
import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET
from unittest import TestCase

import cerberus

import schema

OSM_PATH = "Minneapolis.osm"

NODES_PATH = "nodes1.csv"
NODE_TAGS_PATH = "nodes_tags1.csv"
WAYS_PATH = "ways1.csv"
WAY_NODES_PATH = "ways_nodes1.csv"
WAY_TAGS_PATH = "ways_tags1.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']

         

def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    
    if element.tag == 'node':
        for attrib in element.attrib:
            if attrib in NODE_FIELDS:
                node_attribs[attrib] = element.attrib[attrib]
        
        for child in element:
            node_tag = {}
            if LOWER_COLON.match(child.attrib['k']):
                node_tag['type'] = child.attrib['k'].split(':',1)[0]
                node_tag['key'] = child.attrib['k'].split(':',1)[1]
                node_tag['id'] = element.attrib['id']
                node_tag['value'] = child.attrib['v']
                tags.append(node_tag)
            elif PROBLEMCHARS.match(child.attrib['k']):
                continue
            else:
                node_tag['type'] = 'regular'
                node_tag['key'] = child.attrib['k']
                node_tag['id'] = element.attrib['id']
                node_tag['value'] = child.attrib['v']
                tags.append(node_tag)
                
        
        return {'node': node_attribs, 'node_tags': tags}
        
    elif element.tag == 'way':
        for attrib in element.attrib:
            if attrib in WAY_FIELDS:
                way_attribs[attrib] = element.attrib[attrib]
        
        position = 0
        for child in element:
            way_tag = {}
            way_node = {}
            
            if child.tag == 'tag':
                if LOWER_COLON.match(child.attrib['k']):
                    way_tag['id'] = element.attrib['id']
                    way_tag['key'] = child.attrib['k'].split(':',1)[1]
                    way_tag['type'] = child.attrib['k'].split(':',1)[0]
                    way_tag['value'] = child.attrib['v']
                    tags.append(way_tag)
                elif PROBLEMCHARS.match(child.attrib['k']):
                    continue
                else:
                    way_tag['id'] = element.attrib['id']
                    way_tag['key'] = child.attrib['k']
                    way_tag['type'] = 'addr'
                    way_tag['value'] = child.attrib['v']
                    tags.append(way_tag)
                    
            elif child.tag == 'nd':
                way_node['id'] = element.attrib['id']
                way_node['node_id'] = child.attrib['ref']
                way_node['position'] = position
                position += 1
                way_nodes.append(way_node)
               
                
    return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}


# ================================================== #
#               Helper Functions                     #
# ================================================== #
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()     

class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, str) else v) for k, v in row.items()  
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                    
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])


if __name__ == '__main__':
    process_map(OSM_PATH, validate=True)

# %% [markdown]
# The number of each tag can be found using this script.  It'a worth pointing out that the 'nodes' tags include address information about places of interest, and the 'ways' tags describe streets.  These particular tags will be used in later exploration and cleaning.

# %%
# count number of each tag

import xml.etree.cElementTree as ET
import pprint

def count_tags(filename):
        # YOUR CODE HERE
        tag_count = {}
        for _, element in ET.iterparse(filename, events=("start",)):
            add_tag(element.tag, tag_count)
        return tag_count
        
def add_tag(tag, tag_count):
    if tag in tag_count:
        tag_count[tag] += 1
    else:
        tag_count[tag] = 1


def test():

    tags = count_tags('Minneapolis.osm')
    pprint.pprint(tags)

    

if __name__ == "__main__":
    test()
# Out:
# {'bounds': 1,
#  'member': 49664,
#  'meta': 1,
#  'nd': 335597,
#  'node': 269731,
#  'note': 1,
#  'osm': 1,
#  'relation': 739,
#  'tag': 200062,
#  'way': 45657}

# %% [markdown]
# One issue I noticed while first trying to create the SQL tables is that the elements in the csv files contained byte data that sqlite3 didn't seem to like.  An sample of the nodes1 csv is shown using a data frame.   The function below this output cleans the elements.

# %%
import pandas as pd
nodes_df = pd.read_csv('nodes1.csv')
nodes_df.head(1)
# Out:
#          b'id'         b'lat'          b'lon'       b'user'     b'uid'  \
# 0  b'33295121'  b'44.9748235'  b'-93.2610554'  b'lizzz_msp'  b'992965'
# 1  b'33295122'  b'44.9748579'  b'-93.2611898'      b'Mulad'  b'502142'
# 2  b'33295123'  b'44.9748942'  b'-93.2612886'   b'jumbanho'   b'38487'
# 3  b'33295124'  b'44.9753793'  b'-93.2624228'  b'lizzz_msp'  b'992965'
# 4  b'33295319'  b'44.9660432'  b'-93.3231054'      b'Mulad'  b'502142'
#
#   b'version' b'changeset'             b'timestamp'
# 0       b'7'  b'32418946'  b'2015-07-05T06:34:35Z'
# 1       b'5'   b'9830179'  b'2011-11-14T23:04:24Z'
# 2       b'4'   b'7161078'  b'2011-02-02T01:33:47Z'
# 3       b'6'  b'32418946'  b'2015-07-05T06:34:35Z'
# 4       b'4'  b'25885566'  b'2014-10-05T21:25:25Z'

# %%
# cleaning format of elements in csv files - getting rid of b' at beginning and ' at end 

def clean_csv(infile, outfile):
    inputfile = open(infile, 'r')
    outputfile = open(outfile, 'w')
    for row in inputfile:
        new_row = row.replace("b'", '')
        new_row_2 = new_row.replace("'", '')
        #print(new_row_2)
        outputfile.write(new_row_2+'\n')
    return outputfile

clean_csv("nodes1.csv", "nodes.csv")    
clean_csv("nodes_tags1.csv", "nodes_tags.csv")
clean_csv("ways1.csv", "ways.csv")
clean_csv("ways_nodes1.csv", "ways_nodes.csv")
clean_csv("ways_tags1.csv", "ways_tags.csv")
# Out:
# <_io.TextIOWrapper name='ways_tags.csv' mode='w' encoding='cp1252'>

# %% [markdown]
# # Creating the Database
#
# Now the database and tables can be created.  The tables include: Nodes, and Ways which each have a primary key; the Nodes_Tags, Ways_Tags, and Ways_Nodes tables reference the first two tables via foreign keys.  Some queries are run to explore basic aspects.

# %%
'''  Creating tables using sqlite, database name is Minneapolis.db
     Note the following key relationships:
        Nodes has id as primary key
        Ways has id as primary key
        Nodes_Tags has id as foreign key referencing the Nodes table primary key
        Ways_Tags has id as foreign key referencing the Ways table primary key
        Ways_Nodes has id as foreign key referencing the Ways table primary key
            and node_id as foreign key referencing the Nodes table primary key
'''

import sqlite3
import pandas as pd
from pandas import DataFrame
dbm = db = sqlite3.connect(':memory:') # data base stored in local memory
sqlite3.connect('Minneapolis.db')
c = db.cursor()

# Create Nodes table
c.execute("CREATE TABLE Nodes ([id] integer primary key not null, [lat] float, [lon] float, [user] text, [uid] integer, [version] text, [changeset] integer, [timestamp] text);")
read_clients = pd.read_csv(r'C:\Users\maxgs\DataWrangling_MongoDB\project\nodes.csv')
read_clients.to_sql('Nodes', db, if_exists='append', index = False)
db.commit()

# Create Nodes_Tags table
c.execute("CREATE TABLE Nodes_Tags ([id] integer, [key] text, [value] text, [type] text, foreign key (id) references nodes(id));")
read_clients = pd.read_csv(r'C:\Users\maxgs\DataWrangling_MongoDB\project\nodes_tags.csv')
read_clients.to_sql('Nodes_Tags', db, if_exists='append', index = False)
db.commit()

# Create Ways table
c.execute("CREATE TABLE Ways ([id] integer primary key not null, [user] text, [uid] integer, [version] text, [changeset] integer, [timestamp] text);")
read_clients = pd.read_csv(r'C:\Users\maxgs\DataWrangling_MongoDB\project\ways.csv')
read_clients.to_sql('Ways', db, if_exists='append', index = False)
db.commit()

# Create Ways_Tags table
c.execute("CREATE TABLE Ways_Tags ([id] integer, [key] text, [value] text, [type] text, foreign key (id) references ways(id));")
read_clients = pd.read_csv(r'C:\Users\maxgs\DataWrangling_MongoDB\project\ways_tags.csv')
read_clients.to_sql('Ways_Tags', db, if_exists='append', index = False)
db.commit()

# Create Ways_Nodes table
c.execute("CREATE TABLE Ways_Nodes ([id] integer, [node_id] integer, [position] integer, foreign key (id) references ways(id), foreign key (node_id) references nodes(id));")
read_clients = pd.read_csv(r'C:\Users\maxgs\DataWrangling_MongoDB\project\ways_nodes.csv')
read_clients.to_sql('Ways_Nodes', db, if_exists='append', index = False)
db.commit()

# %% [markdown]
# The number of nodes, ways, unique users can be found using the following queries.

# %%
c.execute('''select count(*) from Nodes''')
print(c.fetchall())
# Out:
# [(1021629,)]

# %%
c.execute('''select count(*) from Ways''')
print(c.fetchall())
# Out:
# [(45657,)]

# %%
c.execute('''select count(distinct(u.uid))
             from (select uid from nodes union all select uid from ways) u;''')
print(c.fetchall())
# Out:
# [(993,)]

# %% [markdown]
# The top 10 contributing users can be found.

# %%
c.execute('''select u.user, count(*) as num
            from (select user from Nodes union all select user from Ways) u
            group by u.user
            order by num desc
            limit 10;''')
print(c.fetchall())
# Out:
# [('iandees', 255732), ('Mulad', 239881), ('stucki1', 139264), ('DavidF', 42753), ('woodpeck_fixbot', 25837), ('sota767', 25510), ('neuhausr', 24357), ('rhardy', 23922), ('houston_mapper1', 23213), ('Arun Balaji', 17339)]

# %% [markdown]
# The number of users with only one contribution can also be queried.

# %%
c.execute('''select count(*) from
             (select u.user, count(*) as num
              from (select user from nodes union all select user from ways) u
              group by u.user
              having num = 1) use;''')
print(c.fetchall())
# Out:
# [(174,)]

# %% [markdown]
# # Cleaning Street Names and Zip Codes
#
# Street names, and the number of their occurances can be queried.

# %%
c.execute('''select tags.value, count(*) as count
             from (select * from Nodes_Tags union all select * from Ways_Tags) tags
             where tags.key = 'street'
             group by tags.value
             order by count desc;''')
print(c.fetchall())
# Out:
# [('Lyndale Avenue South', 129), ('West Lake Street', 120), ('Nicollet Avenue South', 119), ('Hennepin Avenue South', 95), ('Southeast University Avenue', 79), ('Southeast 4th Street', 72), ('Southeast Washington Avenue', 62), ('Southeast 7th Street', 52), ('Bryant Avenue South', 47), ('Southeast 5th Street', 44), ('5th Street SE', 39), ('Southeast 8th Street', 39), ('University Avenue SE', 39), ('Washington Avenue South', 39), ('Lakeview Avenue South', 38), ('Southeast 3rd Avenue', 35), ('Southeast 8th Avenue', 35), ('8th St SE', 34), ('East Lake Street', 32), ('Holmes Avenue South', 32), ('Southeast 14th Avenue', 32), ('Humboldt Avenue South', 31), ('East 38th Street', 28), ('East Franklin Avenue', 28), ('1st Avenue South', 27), ('Colfax Avenue South', 26), ('Northeast Buchanan Street', 23), ('Boardwalk Ave', 22), ('University Avenue Southeast', 21), ('19th Avenue South', 20), ('4th Street SE', 20), ('Cedar Avenue South', 20), ('Northeast Pierce Street', 20), ('Southeast Delaware Street', 20), ('2nd Avenue South', 19), ('3rd Avenue South', 19), ('Hennepin Avenue', 19), ('Irving Avenue South', 19), ('9th St SE', 18), ('Excelsior Boulevard', 18), ('Hall Lane', 18), ('Nicollet Mall', 17), ('South 6th Street', 17), ('Southeast Church Street', 17), ('East 26th Street', 16), ('East Hennepin Avenue', 16), ('Minnehaha Avenue', 16), ('Northeast Central Avenue', 16), ('South 7th Street', 16), ('Southeast 6th Street', 16), ('Southeast Oak Street', 16), ('Stevens Avenue South', 16), ('2nd Avenue SE', 15), ('Harry Davis Ln', 15), ('36th Avenue South', 14), ('Chicago Avenue South', 14), ('Clinton Avenue South', 14), ('Hall Curve', 14), ('Hennepin Av', 14), ('Southeast 13th Avenue', 14), ('Southeast 15th Avenue', 14), ('8th Avenue SE', 13), ('South 2nd Street', 13), ('South 8th Street', 13), ('5th Ave SE', 12), ('6th Street SE', 12), ('East River Parkway', 12), ('Marquette Avenue South', 12), ('South 4th Street', 12), ('5th Avenue SE', 11), ('Lagoon Avenue', 11), ('Southeast Pleasant Street', 11), ('21st Avenue South', 10), ('Central Avenue Northeast', 10), ('Southeast Pillsbury Drive', 10), ('Washington Avenue North', 10), ('23rd Avenue South', 9), ('Blaisdell Avenue South', 9), ('North 2nd Street', 9), ('Park Avenue South', 9), ('Southeast Huron Boulevard', 9), ('West 36th Street', 9), ('25th Avenue South', 8), ('4th Avenue SE', 8), ('Boardwalk Pl', 8), ('Central Ave NE', 8), ('Riverside Avenue', 8), ('South 9th Street', 8), ('Southeast 10th Avenue', 8), ('Southeast Fulton Street', 8), ('Southeast Harvard Street', 8), ('West 35th Street', 8), ('27th Avenue South', 7), ('2nd Ave SE', 7), ('Hennepin Ave E', 7), ('Hiawatha Avenue', 7), ('North 1st Street', 7), ('North Washington Avenue', 7), ('Southeast 5th Avenue', 7), ('22nd Avenue South', 6), ('4th Avenue South', 6), ('7th St SE', 6), ('Bloomington Avenue South', 6), ('East 35th Street', 6), ('Grand Avenue South', 6), ('Lake St W', 6), ('Northeast 13th Avenue', 6), ('Portland Avenue South', 6), ('South 3rd Street', 6), ('Southeast Como Avenue', 6), ('Southeast Essex Street', 6), ('West 26th Street', 6), ('West Franklin Avenue', 6), ('3rd Avenue SE', 5), ('3rd Street North', 5), ('6th Avenue SE', 5), ('Aldrich Avenue South', 5), ('East 19th Street', 5), ('East 28th Street', 5), ('Main Street SE', 5), ('Northeast Broadway Street', 5), ('South 5th Street', 5), ('Southeast 17th Avenue', 5), ('Southeast 7th Street ', 5), ('Southeast Main Street', 5), ('Southeast Ontario Street', 5), ('11th Ave SE', 4), ('13th Avenue Northeast', 4), ('14th Ave N', 4), ('15th Avenue South', 4), ('1st Avenue North', 4), ('20th Avenue South', 4), ('26th Avenue South', 4), ('27th Avenue Southeast', 4), ('28th Avenue South', 4), ('3rd Street South', 4), ('5th St SE', 4), ('Dupont Avenue South', 4), ('East 22nd Street', 4), ('Girard Avenue South', 4), ('Harrison St NE', 4), ('Lasalle Avenue', 4), ('Nicollet Avenue', 4), ('Northeast 2nd Street', 4), ('Northeast Marshall Street', 4), ('Oak St SE', 4), ('Park Avenue', 4 ...

# %% [markdown]
# Inconsistencies with street names and abbreviations such as 'Ave', 'Av', and 'Av.' all being used to describe 'Avenue' can be cleaned up with Python.  The mapping in the code below converts most of the inconsistencies that I found.

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = "Minneapolis.osm"
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE) # find street names



expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

# UPDATE THIS VARIABLE
mapping = { "St": "Street",
            "St.": "Street",
            "Ave": "Avenue",
            "Av": "Avenue",
            "Ave": "Avenue",
            "Rd.": "Road",
            "Pkwy": "Parkway",
            "Rd/Pkwy": "Parkway",
            "Blvd": "Boulevard",
            "Pl": "Place",
            "Terr": "Terrace",
            "Ln": "Lane",
            "N": "North",
            "N.": "North",
            "S": "South",
            "S.": "South",
            "E": "East",
            "E.": "East",
            "W": "West",
            "W.": "West",
            "NE": "Northeast",
            "SE": "Southeast",
            "Norteast": "Northeast"            
            }


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)



def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")



def audit(osmfile):
    osm_file = open(osmfile, "r", encoding ="utf8")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start","end")):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()                
    
    return street_types


def update_name(name, mapping):
    # match street abbreviations according to the above mapping, and replace with words
    m = street_type_re.search(name)
    better_name = name    
    if m and  m.group() in mapping:
        better_name = name.replace(m.group(), mapping[m.group()])
    return better_name



def test():
    st_types = audit(OSMFILE)
    pprint.pprint(dict(st_types))

    for st_type, ways in st_types.items():
        for name in ways:
            better_name = update_name(name, mapping)
            print(name, "=>", better_name)
                              

if __name__ == '__main__':
    test()
# Out:
# {'280': {'E Hennepin Ave, #280'},
#  'Av': {'Lagoon Av', 'Hennepin Av'},
#  'Ave': {'Boardwalk Ave',
#          'E Hennepin Ave',
#          'N Washington Ave',
#          'S Washington Ave'},
#  'Blvd': {'Stinson Blvd', 'Bottineau Blvd'},
#  'Bridge': {'Washington Avenue Bridge'},
#  'Curve': {'Hall Curve'},
#  'E': {'Hennepin Ave E'},
#  'East': {'18th Avenue North East'},
#  'Ln': {'Harry Davis Ln'},
#  'Mall': {'Nicollet Mall'},
#  'N': {'14th Ave N',
#        '3rd St N',
#        '6th Ave N',
#        '913 Plymouth Ave N',
#        'Glenwood Ave N',
#        'Plymouth Ave N'},
#  'N.': {'Washington Ave. N.'},
#  'NE': {'1st Avenue NE',
#         'Broadway St NE',
#         'Central Ave NE',
#         'Fillmore St. NE',
#         'Harrison St NE',
#         'Johnson Street NE',
#         'Marshall Street NE'},
#  'Norteast': {'30th Avenue Norteast'},
#  'North': {'13th Street North',
#            '1st Avenue North',
#            '1st Street North',
#            '2nd Avenue North',
#            '2nd Street North',
#            '3rd Avenue North',
#            '3rd Street North',
#            '4th Avenue North',
#            '5th Street North',
#            '6th Avenue North',
#            '6th Street North',
#            'Colfax Avenue North',
#            'Freemont Avenue North',
#            'Lowry Avenue North',
#            'Oakdale Avenue North',
#            'Plymouth Avenue North',
#            'Thomas Avenue North',
#            'Washington Ave North',
#            'Washington Avenue North',
#            'West River Road North',
#            'Zenith Avenue North'},
#  'Northeast': {'13th Avenue Northeast',
#                '15th Avenue Northeast',
#                '17th Avenue Northeast',
#                '22nd Avenue Northeast',
#                '2nd Street Northeast',
#                '4th Street Northeast',
#                '5th Street Northeast',
#                'Central Avenue Northeast',
#                'Fourth Street Northeast',
#                'Lowry Avenue Northeast',
#                'Quincy Street Northeast'},
#  'Pkwy': {'E River Pkwy'},
#  'Pl': {'Boardwalk Pl'},
#  'Plaza': {'Market Plaza'},
#  'Rd': {'E River Rd'},
#  'Rd/Pkwy': {'East River Rd/Pkwy'},
#  'S': {'19th Ave S',
#        '21st Ave S',
#        '22nd Ave S',
#        '2nd Ave S',
#        'Hennepin Ave S',
#        'James Ave S',
#        'Lyndale Ave S',
#        'Thomas Ave S',
#        'Washington Ave S'},
#  'S.': {'Hennepin Ave. S.'},
#  'SE': {'10th Avenue SE & 5th Street SE',
#         '11th Ave SE',
#         '16th Ave SE',
#         '17th Ave SE',
#         '18th Ave SE',
#         '21st Ave SE',
#         '2nd Ave SE',
#         '2nd Avenue SE',
#         '2nd Street SE',
#         '3rd Avenue SE',
#         '4th Avenue SE',
#         '4th St SE',
#         '4th Street SE',
#         '5th Ave SE',
#         '5th Avenue SE',
#         '5th St SE',
#         '5th Street SE',
#         '6th Avenue SE',
#         '6th St SE',
#         '6th St. SE',
#         '6th Street SE',
#         '7th Avenue SE',
#         '7th St SE',
#         '8th Avenue SE',
#         '8th St SE',
#         '8th Street SE',
#         '9th St SE',
#         'Beacon St SE',
#         'Central Avenue SE',
#         'Church St SE',
#         'Church Street SE',
#         'Delaware St SE',
#         'Delaware Street SE',
#         'Fulton St SE',
#         'Fulton Street SE',
#         'Main Street SE',
#         'Oak St SE',
#         'Ontario St SE',
#         'Pillsbury Dr SE',
#         'Pleasant St SE',
#         'Rollins Avenue SE',
#         'Union St SE',
#         'Union Street SE',
#         'University Ave SE',
#         'University Avenue SE',
#         'Walnut St SE',
#         'Washington Avenue SE'},
#  'Skyway': {'Minneapolis Skyway'},
#  'South': {'10th Avenue South',
#            '11th Avenue South',
#            '12th Avenue South',
#            '13th Avenue South',
#            '14th Avenue South',
#            '15th Avenue South',
#            '16th Avenue South',
#            '17th Avenue South',
#            '19th Avenue South',
#            '1st Avenue South',
#            '20th Avenue South',
#            '21st Avenue South',
#            '22nd Avenue South',
#            '23rd Avenue South',
#            '24th Avenue South',
#            '25th Avenue South',
#            '26th Avenue South',
#            '27th Avenue South',
#            '28th Avenue South',
#            '29th Avenue South',
#            '2nd Ave South',
#            '2nd Avenue South',
#            '2nd Street South',
#            '31st Avenue South',
#            '33rd Avenue South',
#            '36th Avenue South',
#            '3rd Avenue South',
#            '3rd Street South',
#            '4th Avenue South',
#            '4th Street South',
#            '5th Avenue South',
#            '9th Avenue South',
#            'Aldrich Avenue South',
#            'Blaisdell Avenue South',
#            'Bloomington Avenue South',
#            'Bryant Avenue South',
#            'Cedar Avenue South',
#            'Cedar Lake Road South',
#            'Chicago Avenue South',
#            'Clinton Avenue South',
#            'Colfax Avenue South',
#            'Dupont Avenue South',
#            'Emerson Avenue South',
#            'Ewing Avenue South',
#            'Garfield Avenue South',
#            'Girard Avenue South',
#            'Grand Avenue South',
#            'Harriet Avenue South',
#            'Hennepin Avenue South',
#            'Holmes Avenue South',
#            'Humboldt Avenue South',
#            'Irving Avenue South',
#            'James Avenue South',
#            'Lakeview Avenue South',
#            'Lyndale Avenue South',
#            'Marquette Avenue South',
#            'Nicollet Avenue South',
#            'Park Avenue South',
#            'Pillsbury Avenue South',
#            'Pleasant Avenue South',
#            'Portland Avenue South',
#            'Snelling Avenue South',
#            'Stevens Avenue South',
#            'Thomas Avenue South',
#            'Upton Avenue South',
#            'Washington Ave South',
#            'Washington Avenue South',
#            'Willow Street South'},
#  'Southeast': {'14th Avenue Southeast',
#                '15th Avenue Southeast',
#                '27th Avenue Southeast',
#                '2nd Street Southeast',
#                'Central Avenue Southeast',
#                'Main Street Southeast',
#                'Pillsbury Drive Southeast',
#                'Saint Marys Avenue Southeast',
#                'Union Street Southeast',
#                'University Avenue Southeast'},
#  'St': {'Arlington St',
#         'E 38th St',
#         'N 4th St',
#         'NE 7th St',
#         'S 4th St',
#         'S 8th St',
#         'W Lake St'},
#  'Terr': {'Kenzie Terr'},
#  'Terrace': {'Groveland Terrace', 'Franklin Terrace', 'Kenzie Terrace'},
#  'Transitway': {'University of Minnesota Transitway'},
#  'W': {'Lake St W'},
#  'West': {'Laurel Avenue West', '32nd Street West', 'Linden Avenue West'}}
# Grand Avenue South => Grand Avenue South
# Clinton Avenue South => Clinton Avenue South
# 21st Avenue South => 21st Avenue South
# 9th Avenue South => 9th Avenue South
# Humboldt Avenue South => Humboldt Avenue South
# 19th Avenue South => 19th Avenue South
# Bryant Avenue South => Bryant Avenue South
# Portland Avenue South => Portland Avenue South
# 12th Avenue South => 12th Avenue South
# 24th Avenue South => 24th Avenue South
# Dupont Avenue South => Dupont Avenue South
# 28th Avenue South => 28th Avenue South
# 2nd Avenue South => 2nd Avenue South
# 4th Street South => 4th Street South
# 23rd Avenue South => 23rd Avenue South
# Garfield Avenue South => Garfield Avenue South
# Nicollet Avenue South => Nicollet Avenue South
# Colfax Avenue South => Colfax Avenue South
# Snelling Avenue South => Snelling Avenue South
# Aldrich Avenue South => Aldrich Avenue South
# Cedar Lake Road South => Cedar Lake Road South
# Marquette Avenue South => Marquette Avenue South
# 29th Avenue South => 29th Avenue South
# 25th Avenue South => 25th Avenue South
# Pleasant Avenue South => Pleasant Avenue South
# 16th Avenue South => 16th Avenue South
# 10th Avenue South => 10th Avenue South
# 14th Avenue South => 14th Avenue South
# 17th Avenue South => 17th Avenue South
# Irving Avenue South => Irving Avenue South
# Hennepin Avenue South => Hennepin Avenue South
# Holmes Avenue South => Holmes Avenue South
# Ewing Avenue South => Ewing Avenue South
# Bloomington Avenue South => Bloomington Avenue South
# 33rd Avenue South => 33rd Avenue South
# 3rd Street South => 3rd Street South
# Washington Ave South => Washington Ave South
# 2nd Ave South => 2nd Ave South
# Lyndale Avenue South => Lyndale Avenue South
# Park Avenue South => Park Avenue South
# Upton Avenue South => Upton Avenue South
# 13th Avenue South => 13th Avenue South
# Pillsbury Avenue South => Pillsbury Avenue South
# 26th Avenue South => 26th Avenue South
# 20th Avenue South => 20th Avenue South
# 22nd Avenue South => 22nd Avenue South
# Chicago Avenue South => Chicago Avenue South
# Cedar Avenue South => Cedar Avenue South
# Emerson Avenue South => Emerson Avenue South
# Blaisdell Avenue South => Blaisdell Avenue South
# Stevens Avenue South => Stevens Avenue South
# 31st Avenue South => 31st Avenue South
# 15th Avenue South => 15th Avenue South
# Willow Street South => Willow Street South
# 3rd Avenue South => 3rd Avenue South
# 5th Avenue South => 5th Avenue South
# James Avenue South => James Avenue South
# Harriet Avenue South => Harriet Avenue South
# 27th Avenue South => 27th Avenue South
# 2nd Street South => 2nd Street South
# 1st Avenue South => 1st Avenue South
# Lakeview Avenue South => Lakeview Avenue South
# 11th Avenue South => 11th Avenue South
# 36th Avenue South => 36th Avenue South
# Washington Avenue South => Washington Avenue South
# 4th Avenue South => 4th Avenue South
# Thomas Avenue South => Thomas Avenue South
# Girard Avenue South => Girard Avenue South
# Nicollet Mall => Nicollet Mall
# University Avenue Southeast => University Avenue Southeast
# 2nd Street Southeast => 2nd Street Southeast
# Saint Marys Avenue Southeast => Saint Marys Avenue Southeast
# Central Avenue Southeast => Central Avenue Southeast
# 15th Avenue Southeast => 15th Avenue Southeast
# 27th Avenue Southeast => 27th Avenue Southeast
# Union Street Southeast => Union Street Southeast
# Pillsbury Drive Southeast => Pillsbury Drive Southeast
# 14th Avenue Southeast => 14th Avenue Southeast
# Main Street Southeast => Main Street Southeast
# Hall Curve => Hall Curve
# Harry Davis Ln => Harry Davis Lane
# 3rd St N => 3rd St North
# Plymouth Ave N => Plymouth Ave North
# 6th Ave N => 6th Ave North
# Glenwood Ave N => Glenwood Ave North
# 913 Plymouth Ave N => 913 Plymouth Ave North
# 14th Ave N => 14th Ave North
# Boardwalk Ave => Boardwalk Avenue
# N Washington Ave => N Washington Avenue
# S Washington Ave => S Washington Avenue
# E Hennepin Ave => E Hennepin Avenue
# Boardwalk Pl => Boardwalk Place
# 1st Avenue NE => 1st Avenue Northeast
# Fillmore St. NE => Fillmore St. Northeast
# Broadway St NE => Broadway St Northeast
# Marshall Street NE => Marshall Street Northeast
# Harrison St NE => Harrison St Northeast
# Central Ave NE => Central Ave Northeast
# Johnson Street NE => Johnson Street Northeast
# 5th Street Northeast => 5th Street Northeast
# 15th Avenue Northeast => 15th Avenue Northeast
# Central Avenue Northeast => Central Avenue Northeast
# Fourth Street Northeast => Fourth Street Northeast
# 17th Avenue Northeast => 17th Avenue Northeast
# Lowry Avenue Northeast => Lowry Avenue Northeast
# 2nd Street Northeast => 2nd Street Northeast
# 4th Street Northeast => 4th Street Northeast
# 22nd Avenue Northeast => 22nd Avenue Northeast
# Quincy Street Northeast => Quincy Street Northeast
# 13th Avenue Northeast => 13th Avenue Northeast
# 4th Street SE => 4th Street Southeast
# Fulton Street SE => Fulton Street Southeast
# 5th Ave SE => 5th Ave Southeast
# Main Street SE => Main Street Southeast
# 9th St SE => 9th St Southeast
# Oak St SE => Oak St Southeast
# 11th Ave SE => 11th Ave Southeast
# Delaware St SE => Delaware St Southeast
# Pillsbury Dr SE => Pillsbury Dr Southeast
# Fulton St SE => Fulton St Southeast
# Washington Avenue SE => Washington Avenue Southeast
# 6th St SE => 6th St Southeast
# Central Avenue SE => Central Avenue Southeast
# 16th Ave SE => 16th Ave Southeast
# 7th Avenue SE => 7th Avenue Southeast
# University Ave SE => University Ave Southeast
# Delaware Street SE => Delaware Street Southeast
# 21st Ave SE => 21st Ave Southeast
# 3rd Avenue SE => 3rd Avenue Southeast
# 2nd Street SE => 2nd Street Southeast
# Union Street SE => Union Street Southeast
# 6th Street SE => 6th Street Southeast
# University Avenue SE => University Avenue Southeast
# 8th Avenue SE => 8th Avenue Southeast
# 5th Street SE => 5th Street Southeast
# 8th St SE => 8th St Southeast
# 8th Street SE => 8th Street Southeast
# 10th Avenue SE & 5th Street SE => 10th Avenue Southeast & 5th Street Southeast
# 5th Avenue SE => 5th Avenue Southeast
# Beacon St SE => Beacon St Southeast
# 17th Ave SE => 17th Ave Southeast
# 4th St SE => 4th St Southeast
# 4th Avenue SE => 4th Avenue Southeast
# 2nd Avenue SE => 2nd Avenue Southeast
# 7th St SE => 7th St Southeast
# 6th Avenue SE => 6th Avenue Southeast
# Church St SE => Church St Southeast
# Walnut St SE => Walnut St Southeast
# 18th Ave SE => 18th Ave Southeast
# Rollins Avenue SE => Rollins Avenue Southeast
# Pleasant St SE => Pleasant St Southeast
# 6th St. SE => 6th St. Southeast
# Ontario St SE => Ontario St Southeast
# 5th St SE => 5th St Southeast
# Church Street SE => Church Street Southeast
# 2nd Ave SE => 2nd Ave Southeast
# Union St SE => Union St Southeast
# 4th Avenue North => 4th Avenue North
# 6th Avenue North => 6th Avenue North
# 5th Street North => 5th Street North
# 1st Street North => 1st Street North
# Washington Avenue North => Washington Avenue North
# 6th Street North => 6th Street North
# Lowry Avenue North => Lowry Avenue North
# 13th Street North => 13th Street North
# West River Road North => West River Road North
# Oakdale Avenue North => Oakdale Avenue North
# 2nd Street North => 2nd Street North
# Freemont Avenue North => Freemont Avenue North
# 3rd Street North => 3rd Street North
# Thomas Avenue North => Thomas Avenue North
# 3rd Avenue North => 3rd Avenue North
# 2nd Avenue North => 2nd Avenue North
# Washington Ave North => Washington Ave North
# Plymouth Avenue North => Plymouth Avenue North
# Colfax Avenue North => Colfax Avenue North
# 1st Avenue North => 1st Avenue North
# Zenith Avenue North => Zenith Avenue North
# Washington Ave. N. => Washington Ave. North
# Lyndale Ave S => Lyndale Ave South
# Hennepin Ave S => Hennepin Ave South
# 21st Ave S => 21st Ave South
# 22nd Ave S => 22nd Ave South
# 2nd Ave S => 2nd Ave South
# James Ave S => James Ave South
# 19th Ave S => 19th Ave South
# Thomas Ave S => Thomas Ave South
# Washington Ave S => Washington Ave South
# Groveland Terrace => Groveland Terrace
# Franklin Terrace => Franklin Terrace
# Kenzie Terrace => Kenzie Terrace
# Stinson Blvd => Stinson Boulevard
# Bottineau Blvd => Bottineau Boulevard
# 30th Avenue Norteast => 30th Avenue Northeast
# Hennepin Ave. S. => Hennepin Ave. South
# N 4th St => N 4th Street
# NE 7th St => NE 7th Street
# W Lake St => W Lake Street
# E 38th St => E 38th Street
# S 4th St => S 4th Street
# Arlington St => Arlington Street
# S 8th St => S 8th Street
# E Hennepin Ave, #280 => E Hennepin Ave, #280
# University of Minnesota Transitway => University of Minnesota Transitway
# Laurel Avenue West => Laurel Avenue West
# 32nd Street West => 32nd Street West
# Linden Avenue West => Linden Avenue West
# Hennepin Ave E => Hennepin Ave East
# Lagoon Av => Lagoon Avenue
# Hennepin Av => Hennepin Avenue
# Minneapolis Skyway => Minneapolis Skyway
# Lake St W => Lake St West
# Market Plaza => Market Plaza
# Washington Avenue Bridge => Washington Avenue Bridge
# E River Rd => E River Rd
# 18th Avenue North East => 18th Avenue North East
# E River Pkwy => E River Parkway
# East River Rd/Pkwy => East River Parkway
# Kenzie Terr => Kenzie Terrace

# %% [markdown]
# Some innacuracies in zip codes were also found.  This query returns counts of zip codes.  I was a little surprised to not find many inconsistencies here.  There is one zip code that only has 3 digits.  While I think it's fine to include 4 digit extensions with zip codes, it feels more consistent to have them all appear in the 5-digit format.

# %%
c.execute('''select tags.value, count(*) as count
             from (select * from Nodes_Tags union all select * from Ways_Tags) tags
             where tags.key = 'postcode'
             group by tags.value
             order by count desc;''')
print(c.fetchall())
# Out:
# [('55414', 671), ('55408', 390), ('55455', 209), ('55404', 140), ('55406', 113), ('55405', 90), ('55401', 75), ('55454', 62), ('55403', 60), ('55416', 49), ('55413', 47), ('55407', 46), ('55418', 42), ('55415', 38), ('55402', 36), ('55409', 19), ('55411', 12), ('55455-0153', 5), ('55422', 3), ('55455-0367', 3), ('55412', 2), ('55414-3026', 2), ('55414-3063', 2), ('55455-3002', 2), ('55101', 1), ('554', 1), ('55402-2368', 1), ('55402-9998', 1), ('55403-2006', 1), ('55403-3933', 1), ('55411-4398', 1), ('55414-2015', 1), ('55414-2016', 1), ('55414-2051', 1), ('55414-2475', 1), ('55414-2919', 1), ('55414-2921', 1), ('55414-3017', 1), ('55414-3022', 1), ('55414-3029', 1), ('55415-1226', 1), ('55418-3510', 1), ('55418-4714', 1), ('55419', 1), ('55423', 1), ('55454-1015', 1), ('55454-1313', 1), ('55455-0200', 1), ('55455-0226', 1), ('55455-0236', 1), ('55455-0237', 1), ('55455-0240', 1), ('55455-0366', 1), ('55455-0425', 1), ('55455-0441', 1), ('55455-0442', 1), ('55455-0485', 1), ('55455-0500', 1), ('55455-1502', 1), ('55455-3003', 1), ('55455-3006', 1), ('55455-3027', 1), ('55488', 1)]

# %% [markdown]
# This python code cleans zip codes in a similiar manner to the address auditing script.  The expected zip codes were found from https://www.zip-codes.com/city/mn-minneapolis.asp.

# %%
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = "Minneapolis.osm"

expected = ['5540\d{1}', '5541\d{1}', '5542\d{1}', '5543\d{1}', '5544\d{1}', '55450', '55454', '55455', '55458',
            '55459', '55460', '55467', '55470', '55472', '55474', '55478', '55479', '55480', '55483', '55484'
            '55485', '55486', '55487', '55488']
zip_map ={}
postal_re = re.compile(r'(\d{5})')  # find 5 digit postal code


def audit_post_code(zip_codes, post_code):
    m = postal_re.search(post_code)
    if m:
        zip_code = m.group()
        if zip_code not in expected:
            zip_codes[zip_code].add(post_code)

def is_post_code(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit(osmfile):
    osm_file = open(osmfile, "r", encoding ="utf8")
    post_codes = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start","end")):            
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_post_code(tag):
                    audit_post_code(post_codes, tag.attrib['v']) 
    osm_file.close()
    return post_codes

print(audit(OSMFILE))

def update_zip(post, zip_map):
    m = postal_re.search(post)
    better_post = post
    if m and m.group()  in zip_map:
        better_post = post.replace(m.group(), mapping[m.group()])
        
    return better_post

def test():
    zip_codes = audit(OSMFILE)

    for zp_code, nodes in zip_codes.items():
        for post in nodes:
            #print(post)
            if len(post) == 5:
                 better_post = update_zip(post, zip_map)
                 print(post, "=>", better_post)
                              

if __name__ == '__main__':
    test()
# Out:
# defaultdict(<class 'set'>, {'55414': {'55414-3063', '55414-2015', '55414-3022', '55414-2475', '55414-2921', '55414', '55414-3026', '55414-2016', '55414-2051', '55414-3029', '55414-3017', '55414-2919'}, '55406': {'55406'}, '55416': {'55416'}, '55408': {'55408'}, '55403': {'55403', '55403-2006', '55403-3933'}, '55402': {'55402', '55402-2368', '55402-9998'}, '55405': {'55405'}, '55404': {'55404'}, '55401': {'55401'}, '55407': {'55407'}, '55409': {'55409'}, '55411': {'55411-4398', '55411'}, '55418': {'55418-4714', '55418-3510', '55418'}, '55415': {'55415-1226', '55415'}, '55413': {'55413'}, '55422': {'55422'}, '55412': {'55412'}, '55101': {'55101'}, '55423': {'55423'}, '55419': {'55419'}})
# 55414 => 55414
# 55406 => 55406
# 55416 => 55416
# 55408 => 55408
# 55403 => 55403
# 55402 => 55402
# 55405 => 55405
# 55404 => 55404
# 55401 => 55401
# 55407 => 55407
# 55409 => 55409
# 55411 => 55411
# 55418 => 55418
# 55415 => 55415
# 55413 => 55413
# 55422 => 55422
# 55412 => 55412
# 55101 => 55101
# 55423 => 55423
# 55419 => 55419

# %% [markdown]
# # Further Exploration

# %% [markdown]
# Querying phone numbers reveals inconsistencies in thier formats.  Using Python to clean that data similiar to what was done with street names and zip codes is another task that could be performed.

# %%
c.execute('''select tags.value, count(*) as count
             from (select * from Nodes_Tags union all select * from Ways_Tags) tags
             where tags.key = 'phone'
             group by tags.value
             order by count desc;''')
print(c.fetchall())
# Out:
# [('612-273-8383', 3), ('+1-763-221-5525', 2), ('16123318100', 2), ('612-331-5000', 2), ('612-331-7474', 2), ('612-370-4925', 2), ('612-822-6088', 2), ('612-823-8095', 2), ('612-870-1976', 2), ('800-275-8777', 2), ('(414) 839-5565', 1), ('(612) 227-9635', 1), ('(612) 236-4429', 1), ('(612) 238-8888', 1), ('(612) 248-8111', 1), ('(612) 259-7519', 1), ('(612) 331-4724', 1), ('(612) 332-4393', 1), ('(612) 333-4242', 1), ('(612) 338-8401', 1), ('(612) 341-2112', 1), ('(612) 379-2259', 1), ('(612) 404 0056', 1), ('(612) 465-8780', 1), ('(612) 481-7551', 1), ('(612) 607-5016', 1), ('(612) 643-1933', 1), ('(612) 781-6529', 1), ('(612) 789-7238', 1), ('(612) 789-8851', 1), ('(612) 823-0977', 1), ('(612) 823-6233', 1), ('(612) 824-6665', 1), ('(612) 825-9922', 1), ('(612) 926-8626', 1), ('(612) 999-4200', 1), ('+ 612 789 4996', 1), ('+1 (612) 371 3100', 1), ('+1 (612) 379-1723', 1), ('+1 (612) 758-0105', 1), ('+1 (612)-354-2453', 1), ('+1 612 204 5000', 1), ('+1 612 206 3920', 1), ('+1 612 208 1450', 1), ('+1 612 225 6499', 1), ('+1 612 230 5575', 1), ('+1 612 235 4970', 1), ('+1 612 236 4831', 1), ('+1 612 236 4870', 1), ('+1 612 238 3593', 1), ('+1 612 253 4100', 1), ('+1 612 260 8890', 1), ('+1 612 273 3000', 1), ('+1 612 273 8383', 1), ('+1 612 315 3945', 1), ('+1 612 321 0100', 1), ('+1 612 325 0817', 1), ('+1 612 326 1326', 1), ('+1 612 330 1000', 1), ('+1 612 332 0880', 1), ('+1 612 332 1011', 1), ('+1 612 332 3651', 1), ('+1 612 332 4700', 1), ('+1 612 3322739', 1), ('+1 612 333 1339', 1), ('+1 612 333 2606', 1), ('+1 612 333 4719', 1), ('+1 612 3332644', 1), ('+1 612 338 9850', 1), ('+1 612 339 3023', 1), ('+1 612 339 4444', 1), ('+1 612 339 7011', 1), ('+1 612 339-6633', 1), ('+1 612 341 3333', 1), ('+1 612 341 5000', 1), ('+1 612 341 8007', 1), ('+1 612 341-7555', 1), ('+1 612 345 4348', 1), ('+1 612 345 4664', 1), ('+1 612 348 3000', 1), ('+1 612 353 6207', 1), ('+1 612 354 7251', 1), ('+1 612 371 5656', 1), ('+1 612 371 9565', 1), ('+1 612 3743635', 1), ('+1 612 375 2200', 1), ('+1 612 375 7600', 1), ('+1 612 376 8000', 1), ('+1 612 377 2224', 1), ('+1 612 377 2278', 1), ('+1 612 377 3448', 1), ('+1 612 377 3734', 1), ('+1 612 377 6108', 1), ('+1 612 379 0838', 1), ('+1 612 379 2368', 1), ('+1 612 379 4909', 1), ('+1 612 379 5040', 1), ('+1 612 454 0455', 1), ('+1 612 455 5100', 1), ('+1 612 455 7500', 1), ('+1 612 486 5500', 1), ('+1 612 524 8414', 1), ('+1 612 578 7897', 1), ('+1 612 617 7793', 1), ('+1 612 624 7591', 1), ('+1 612 668 2720', 1), ('+1 612 668 4300', 1), ('+1 612 673 5703', 1), ('+1 612 676 1947', 1), ('+1 612 677 1100', 1), ('+1 612 706 7950', 1), ('+1 612 721 3011', 1), ('+1 612 721 3141', 1), ('+1 612 721 4868', 1), ('+1 612 721 7087', 1), ('+1 612 722 2500', 1), ('+1 612 722 6612 ', 1), ('+1 612 724 3621', 1), ('+1 612 728 8300', 1), ('+1 612 729 0437', 1), ('+1 612 729 5222', 1), ('+1 612 729 9095', 1), ('+1 612 752 7000', 1), ('+1 612 767 3322', 1), ('+1 612 767 5600', 1), ('+1 612 767 9495', 1), ('+1 612 772 1000', 1), ('+1 612 775 4900', 1), ('+1 612 775 8800', 1), ('+1 612 781 2619', 1), ('+1 612 781 3000', 1), ('+1 612 781 3046', 1), ('+1 612 781 4946', 1), ('+1 612 781 6941', 1), ('+1 612 781 9858', 1), ('+1 612 787 7433', 1), ('+1 612 788 4000', 1), ('+1 612 789 0775', 1), ('+1 612 789 2526', 1), ('+1 612 789 5148', 1), ('+1 612 789 8134', 1), ('+1 612 813 6000', 1), ('+1 612 813 8300', 1), ('+1 612 822 0022', 1), ('+1 612 822 2240', 1), ('+1 612 822 3121', 1), ('+1 612 8228260', 1), ('+1 612 823 4790', 1), ('+1 612 8237217', 1), ('+1 612 8244417', 1), ('+1 612 8249777', 1), ('+1 612 825 1701', 1), ('+1 612 825 2440', 1), ('+1 612 825 6863', 1), ('+1 612 827 7181', 1), ('+1 612 843-0400', 1), ('+1 612 863 4000', 1), ('+1 612 870 4466', 1), ('+1 612 870 4739', 1), ('+1 612 870 7800', 1), ('+1 612 870 9842', 1), ('+1 612 871 2211', 1), ('+1 612 871 5303', 1), ('+1 612 872 2323', 1), ('+1 612 872 8086', 1), ('+1 612 873 3000', 1), ('+1 612 874 0716', 1), ('+1 612 874 8867', 1), ('+1 612 886 2377',  ...

# %% [markdown]
# Finally, I think it's interesting to find the most frequent appearing types of places included in the osm file.

# %%
c.execute('''select value, count(*) as num
             from nodes_tags
             where key = 'amenity'
             group by value
             order by num desc
             limit 10;''')
print(c.fetchall())
# Out:
# [('restaurant', 291), ('bicycle_parking', 203), ('bench', 136), ('cafe', 100), ('bicycle_rental', 97), ('fast_food', 57), ('waste_basket', 44), ('parking_entrance', 43), ('pu', 41), ('bar', 38)]
